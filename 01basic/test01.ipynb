# %%
print("hello python")
# Out:
# hello python

# %%
# !python --version
# Out:
# Python 3.13.9

# %%
age = 20
print(age)
# Out:
# 20

# %%
print(f'test{age}')
# Out:
# test20

# %%
print(f'your age is {age}.')
# Out:
# your age is 20.

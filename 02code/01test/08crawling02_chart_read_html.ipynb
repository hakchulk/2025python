# %%
import requests
from io import StringIO
import pandas as pd

url = 'https://www.melon.com/chart/'

# headers 이 없으면 에러. Edge: Too Many Requests
headers = {"User-Agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36'
           ,'accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7'
        }
res = requests.get(url, headers=headers)
chart = pd.read_html( StringIO(str(res.text)), header=0)[0]
print( chart.shape )
print( type(chart ) )
chart 
# 1. '순위'와 '곡정보' 컬럼만 선택
filtered_chart = chart[['순위', '곡정보']]

# 2. 결과 출력 (상위 5개)
# print(filtered_chart.head())
for index, row in chart.iterrows():
    rank = row['순위']
    info = row['곡정보']   
    print(f"{rank} - {info}")
# Out:
# (100, 12)
# <class 'pandas.core.frame.DataFrame'>
# 1위 - Good Goodbye  화사 (HWASA)
# 2위 - 타임캡슐  다비치
# 3위 - Drowning  WOODZ
# 4위 - Blue Valentine  NMIXX
# 5위 - 사랑하게 될 거야  한로로
# 6위 - SPAGHETTI (feat. j-hope of BTS)  LE SSERAFIM (르세라핌), j-hope
# 7위 - ONE MORE TIME  ALLDAY PROJECT
# 8위 - Golden  HUNTR/X, EJAE, AUDREY NUNA, REI AMI, KPop Demon Hunters Cast
# 9위 - 멸종위기사랑  이찬혁
# 10위 - 힙합보단 사랑, 사랑보단 돈 (Feat. 베이식)  노아주다 (noahjooda)
# 11위 - 어제보다 슬픈 오늘  우디 (Woody)
# 12위 - 뛰어(JUMP)  BLACKPINK
# 13위 - 하얀 그리움  프로미스나인
# 14위 - 달리 표현할 수 없어요  로이킴
# 15위 - Zoo (From "Zootopia 2"/Soundtrack Version)  Disney, Shakira
# 16위 - 0+0  한로로
# 17위 - 첫 눈  EXO
# 18위 - FAMOUS  ALLDAY PROJECT
# 19위 - NOT CUTE ANYMORE  아일릿(ILLIT)
# 20위 - 모르시나요(PROD.로코베리)  조째즈
# 21위 - toxic till the end  로제 (ROSÉ)
# 22위 - HOME SWEET HOME (feat. 태양, 대성)  G-DRAGON
# 23위 - Soda Pop  KPop Demon Hunters Cast, Danny Chung, Saja Boys, Andrew Choi, Neckwav, Kevin Woo, samUIL Lee
# 24위 - 너의 모든 순간  성시경
# 25위 - like JENNIE  제니 (JENNIE)
# 26위 - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지  AKMU (악뮤)
# 27위 - 내게 사랑이 뭐냐고 물어본다면  로이킴
# 28위 - 천상연  이창섭
# 29위 - 시작의 아이 ❍  박다혜, 마크툽 (MAKTUB)
# 30위 - 오늘만 I LOVE YOU  BOYNEXTDOOR
# 31위 - 너에게 닿기를  10CM
# 32위 - 청춘만화  이무진
# 33위 - 나는 반딧불  황가람
# 34위 - OVERDRIVE  TWS (투어스)
# 35위 - REBEL HEART  IVE (아이브)
# 36위 - Whiplash  aespa
# 37위 - Hollywood Action  BOYNEXTDOOR
# 38위 - IRIS OUT  Kenshi Yonezu
# 39위 - HAPPY  DAY6 (데이식스)
# 40위 - XOXZ  IVE (아이브)
# 41위 - 한 페이지가 될 수 있게  DAY6 (데이식스)
# 42위 - 한번 더 이별  이창섭
# 43위 - 모든 날, 모든 순간 (Every day, Every Moment)  폴킴
# 44위 - 사랑은 늘 도망가  임영웅
# 45위 - 소나기  이클립스 (ECLIPSE)
# 46위 - 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))  너드커넥션 (Nerd Connection)
# 47위 - FOCUS  Hearts2Hearts (하츠투하츠)
# 48위 - APT.  로제 (ROSÉ), Bruno Mars
# 49위 - 눈사람  정승환
# 50위 - Rich Man  aespa
# 51위 - 예뻤어  DAY6 (데이식스)
# 52위 - Welcome to the Show  DAY6 (데이식스)
# 53위 - 운명 (2025)  먼데이 키즈, 이이경
# 54위 - 시작의 아이  마크툽 (MAKTUB)
# 55위 - Never Ending Story  아이유
# 56위 - Flower  오반(OVAN)
# 57위 - 365일  이창섭
# 58위 - TOO BAD (feat. Anderson .Paak)  G-DRAGON
# 59위 - Love wins all  아이유
# 60위 - 첫 만남은 계획대로 되지 않아  TWS (투어스)
# 61위 - 그래 늦지 않았어 (2025)  아샤트리, 이예은, 전건호
# 62위 - Die With A Smile  Lady Gaga, Bruno Mars
# 63위 - 눈이 오잖아(Feat.헤이즈)  이무진
# 64위 - STYLE  Hearts2Hearts (하츠투하츠)
# 65위 - DUET  지코 (ZICO), Lilas
# 66위 - I AM  IVE (아이브)
# 67위 - 주저하는 연인들을 위해  잔나비
# 68위 - 다정히 내 이름을 부르면  경서예지, 전건호
# 69위 - 청혼하지 않을 이유를 못 찾았어  이무진
# 70위 - Dirty Work  aespa
# 71위 - 빌려온 고양이 (Do the Dance)  아일릿(ILLIT)
# 72위 - 사랑인가 봐  멜로망스
# 73위 - 나였으면  나윤권, 도경수(D.O.)
# 74위 - body  다영 (DAYOUNG)
# 75위 - Magnetic  아일릿(ILLIT)
# 76위 - LOOK AT ME  ALLDAY PROJECT
# 77위 - 에피소드  이무진
# 78위 - 인사  범진
# 79위 - 순간을 영원처럼  임영웅
# 80위 - 헤어지자 말해요  박재정
# 81위 - Supernova  aespa
# 82위 - MY LOVE(2025)  이예은, 아샤트리, 전건호
# 83위 - 가만히 눈을 감고  DK(디셈버)
# 84위 - Seven (feat. Latto) - Clean Ver.  정국
# 85위 - 우리들의 블루스  임영웅
# 86위 - 비의 랩소디  임재현
# 87위 - 슬픈 초대장  순순희(지환)
# 88위 - Hype Boy  NewJeans
# 89위 - 다시 만날 수 있을까  임영웅
# 90위 - BBUU!  PLAVE
# 91위 - WICKED  ALLDAY PROJECT
# 92위 - 고민중독  QWER
# 93위 - 들꽃이 될게요  임영웅
# 94위 - 그댈 위한 멜로디  임영웅
# 95위 - 이 밤을 빌려 말해요  PLAVE
# 96위 - DRIP  BABYMONSTER
# 97위 - Must Have Love  SG 워너비, 브라운아이드걸스
# 98위 - MEGA PIECE HARMONY  하데스(HADES)
# 99위 - 비가 와서  임영웅
# 100위 - Dash  PLAVE

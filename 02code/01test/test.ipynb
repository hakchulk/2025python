# %% [markdown]
# # 제목
# ## 제목
# ### 제목
# ###### 제목
# **제목**
# 제목
# - 테이터 수집
# - 데이터 전처리
#     - 결측치
#     - 이상치
#
# 1. 데이터불러오기
# 1. 모델학습
# 1. 결과
#
# `print("hello python")`
# ```print
# print("hello python")
# df=pd.read_csv("abc.csv")
# ```
# ---
#
# |컬럼|설명|
# |----|----|
# |x      | 입력|
#
# 구글링크 : [구글](http://www.google.com)
# ![이미지](이미지경로)
# ---
# - [x] 데이터로드
# - [ ] test
#
# [이미지](URL)
#
# [노션경로](https://www.notion.so/travly-2657bdfe79608093a275c22daf43ca3e)

# %%
a = int( input('정수:' ) )
b = int( input('정수:' ) )
print(a + b)
# Out:
# 50

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
c = float( input('시간입력:') )
d = c * 3660
print(f'{d}초')
# Out:
# 3660.0초

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
# plt.plot(x, y)
plt.bar(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
score = [60, 65, 70, 80, 90]    
plt.scatter(x, score)
plt.xlabel('number')
plt.ylabel('score')
plt.show()

# %%
import random
r = random.randint(1, 3)
print(r)
answer = int( input('정답입력:') )
if r == answer:
    print('정답') 
else:
    print('wrong') 
print(f'정답은 {r}입니다.')
# Out:
# 3
# wrong
# 정답은 3입니다.

# %%
text = ['서울', '부산', '대구', '인천', '광주']
# c =random.randint(0, 4)
c =random.randint(0, len(text)-1)
print(f'선택된 도시: {text[c]}')
# Out:
# 선택된 도시: 부산

# %% [markdown]
# ### range(start, stop, step)
# ### range(stop)

# %%
a = range(1,6,2)
print(a)
for i in a:
    print(i)
# Out:
# range(1, 6, 2)
# 1
# 3
# 5

# %%
for i in range(1,6,1):
    print(f'{i}:{text[i-1]}')
# Out:
# 1:서울
# 2:부산
# 3:대구
# 4:인천
# 5:광주

# %%
import random

numbers = list(range(1, 11))
# print(numbers)
lotto = random.sample(numbers, 6)
print(type(lotto))
print(f'로또번호: {lotto}')
lotto.sort()
print(f'로또번호: {lotto}')

# %%
for i in 1,6,4:
    print(i)

# %%
for i in range(5):
    print(text[i])
# Out:
# 서울
# 부산
# 대구
# 인천
# 광주

# %%
import random
a = random.randint(1, 100)
b = random.randint(1, 100)

print(a, b)      
if a < b:
    a, b = a, b
else:
    a, b = b, a

print(a, b)
# Out:
# 47 32
# 32 47

# %%
# 두 학생의 키 차이
a = int( input('학생1:') )
b = int( input('학생2:') )

if a < b:
    print('키 차이:',b - a)
else:
    print('키 차이:',a - b)
# Out:
# 키 차이 1005

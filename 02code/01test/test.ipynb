# %% [markdown]
# # 제목
# ## 제목
# ### 제목
# ###### 제목
# **제목**
# 제목
# - 테이터 수집
# - 데이터 전처리
#     - 결측치
#     - 이상치
#
# 1. 데이터불러오기
# 1. 모델학습
# 1. 결과
#
# `print("hello python")`
# ```print
# print("hello python")
# df=pd.read_csv("abc.csv")
# ```
# ---
#
# |컬럼|설명|
# |----|----|
# |x      | 입력|
#
# 구글링크 : [구글](http://www.google.com)
# ![이미지](이미지경로)
# ---
# - [x] 데이터로드
# - [ ] test

# %%
print("hello world")
# Out:
# hello world

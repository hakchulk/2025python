# %%
pricese = {'아메리카노': 2500, '카페라떼': 3000, '카푸치노': 3500}
for coffee, price in pricese.items():
    print(f"{coffee}의 가격은 {price}원 입니다.")
# Out:
# 아메리카노의 가격은 2500원 입니다.
# 카페라떼의 가격은 3000원 입니다.
# 카푸치노의 가격은 3500원 입니다.

# %%
# a = pricese.pop('카페라떼')
# print(f"카페라떼의 가격은 {a}원 입니다.")
print(type(pricese['카푸치노']))
del 3500
# del pricese['카푸치노']
pricese
# Out:
#   Cell In[14], line 4
#     del 3500
#         ^
# SyntaxError: cannot delete literal

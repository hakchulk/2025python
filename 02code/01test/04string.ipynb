# %%
st = "이름 : '홍길동'\n나이 : 20\n주소 : 서울시 강남구\n취미 : 축구"
print(st)
# Out:
# 이름 : '홍길동'
# 나이 : 20
# 주소 : 서울시 강남구
# 취미 : 축구

# %%
st2 = "이름 : '홍길동'"

for i in range(len(st2)):
    c = st2[i]
    print(c,end='' if i == len(st2)-1 else '-')
# Out:
# 이-름- -:- -'-홍-길-동-'

# %%
st3 = "abcde"
print(st3[1:len(st3)])
# Out:
# bcde

# %%
st4 = "hello"
for i in range(len(st4)-1, -1, -1):
    print(st4[i], end='')
st4[::-1]
# Out:
# olleh
# 'olleh'

# %%
lower_list = []

while True:
    s = input("영어단어:")
    if s == "exit":
        break
    lower_list.append(s.lower())

for w in lower_list:
    print(w)
# Out:
# the
# red
# wheelbarrow

# %%
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split

tf.keras.utils.set_random_seed(42)

# %%
(train_input,train_target),(test_input,test_target) = keras.datasets.fashion_mnist.load_data()
print(train_input.shape, train_target.shape)
print(test_input.shape, test_target.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %%
train_scaled = train_input.reshape(-1,28,28,1) / 255.0 # CNN 모델을 사용하기 위해서 4차원 텐서로 변환
train_scaled.shape
# Out:
# (60000, 28, 28, 1)

# %%
train_scaled, val_scaled, train_target, val_target = train_test_split(
    train_scaled, train_target, test_size=0.2, random_state=42
)

# %%
model = keras.Sequential() # 모델을 순차적으로 쌓아올리는 방식

# %%
# 32: 사용할 필터(커널)의 개수입니다. 각 필터는 이미지에서 특정 패턴을 감지하는 역할을 합니다. 더 많은 필터를 사용하면 모델이 더 다양한 패턴을 학습할 수 있지만, 계산 비용이 증가할 수 있습니다.
# kernel_size=3: 필터의 크기가 3x3입니다. 작은 필터는 이미지에서 작은 패턴을 감지하는 데 유용합니다.
# activation='relu': 찾은 특징들 중 의미 있는 신호만 강조하고 나머지는 0으로 만듭니다. (비선형성 추가)
model.add(keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding='same', input_shape=(28,28,1)))
# Out:
# c:\hak\kdev\03python\02code\01test\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(keras.layers.MaxPooling2D(2))

# %%
# padding='same' : 출력 크기가 입력 크기와 같도록 패딩을 추가
model.add(keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu', padding='same', input_shape=(28,28,1)))
model.add(keras.layers.MaxPooling2D(2))

# %%
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(100, activation='relu'))
model.add(keras.layers.Dropout(0.4)) # 과적합 방지 위해 Dropout 층 추가, 0.4는 40%의 뉴런을 무작위로 끔
model.add(keras.layers.Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 3136)           │             0 │
# ...

# %%
# import visualkeras
# visualkeras.layered_view(model, legend=True)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['acc']

)

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-cnn-model.keras',save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2, restore_best_weights=True)

history = model.fit(train_scaled, train_target, 
                    epochs=20, 
                    callbacks=[checkpoint_cb,early_stopping_cb],
                    validation_data=(val_scaled,val_target)
                    )
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - acc: 0.8124 - loss: 0.5257 - val_acc: 0.8758 - val_loss: 0.3327
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - acc: 0.8751 - loss: 0.3491 - val_acc: 0.8948 - val_loss: 0.2832
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 13ms/step - acc: 0.8913 - loss: 0.3002 - val_acc: 0.9036 - val_loss: 0.2606
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - acc: 0.9030 - loss: 0.2675 - val_acc: 0.9111 - val_loss: 0.2467
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - acc: 0.9111 - loss: 0.2457 - val_acc: 0.9148 - val_loss: 0.2387
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - acc: 0.9176 - loss: 0.2228 - val_acc: 0.9151 - val_loss: 0.2369
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 22s 14ms/step - acc: 0.9231 - loss: 0.2081 - val_acc: 0.9186 - val_loss: 0.2389
# Epoch 8/20
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - acc: 0.9213 - loss: 0.2325
# [0.23251082003116608, 0.9213333129882812]

# %%
plt.imshow(val_scaled[2].reshape(28,28), cmap='gray_r')
plt.show()

# %%
preds = model.predict(val_scaled[2:3])
print(preds)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# [[6.8610368e-13 2.7787298e-18 2.3287964e-16 1.0299997e-18 1.8353844e-15
#   5.0034565e-10 6.0152378e-16 9.9999988e-01 2.8035744e-15 1.6691922e-07]]

# %% [markdown]
# 레이블 (Label),아이템 이름 (Description),한국어 의미
# 0,T-shirt/top,티셔츠
# 1,Trouser,바지
# 2,Pullover,스웨터 (풀오버)
# 3,Dress,드레스
# 4,Coat,코트
# 5,Sandal,샌들
# 6,Shirt,셔츠
# 7,Sneaker,스니커즈
# 8,Bag,가방
# 9,Ankle boot,앵클 부츠

# %%
import numpy as np
class_names = ['T-shirt', '바지', '스웨터', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(class_names[np.argmax(preds)])
# Out:
# Sneaker
